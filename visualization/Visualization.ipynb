# %% [markdown]
# # OLA Data Analyst – Visualization Questions

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mlt

# %% [markdown]
# ## CSV File Config

# %%
df=pd.read_csv("../data_generation/kola_bookings.csv")

# %% [markdown]
# ## 🔹 Booking Performance

# %% [markdown]
# ### 1. How many total bookings were made, and how many were successful vs cancelled vs incomplete?

# %%
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'Avg_VTAT',
#        'Avg_CTAT', 'Cancelled_Rides_by_Customer',
#        'Reason_for_cancelling_by_Customer', 'Cancelled_Rides_by_Driver',
#        'Driver_Cancel_Reason', 'Incomplete_Rides', 'Incomplete_Rides_Reason',
#        'Booking_Value', 'Payment_Method', 'Ride_Distance', 'Driver_Ratings',
#        'Customer_Rating'],
#       dtype='object')

# %% [markdown]
# ### 2. What is the percentage distribution of booking status (Success, Cancelled by Customer, Cancelled by Driver, Incomplete)?

# %% [markdown]
# ### 3. How does booking volume vary across different days of the month?

# %% [markdown]
# ### 4. What is the trend of successful bookings over time?

# %% [markdown]
# ## 🔹 Revenue & Value Analysis

# %% [markdown]
# ### 1. What is the total revenue generated from successful rides?

# %% [markdown]
# ### 2. How does total revenue compare between weekdays and weekends?

# %% [markdown]
# ### 3. Which payment method contributes the highest total revenue?

# %% [markdown]
# ### 4. What is the average booking value by vehicle type?

# %% [markdown]
# ### 5. What proportion of bookings fall under:
# - Below ₹500
# - ₹500–₹1000
# - Above ₹1000

# %% [markdown]
# ## 🔹 Vehicle & Ride Analysis

# %% [markdown]
# ### 1. What is the average ride distance for each vehicle type?

# %% [markdown]
# ### 2. Which vehicle type has the highest average ride distance?

# %% [markdown]
# ### 3. How does ride distance distribution vary across vehicle types?

# %% [markdown]
# ### 4. What is the relationship between ride distance and booking value?

# %% [markdown]
# ## 🔹 Customer Behavior Analysis

# %% [markdown]
# ### 1. Who are the top 5 customers by number of rides booked?

# %% [markdown]
# ### 2. How many customers have repeated cancellations?

# %% [markdown]
# ### 3. What percentage of customers cancel more than once?

# %% [markdown]
# ### 4. What is the distribution of customer ratings across vehicle types?

# %% [markdown]
# ## 🔹 Cancellation Analysis

# %% [markdown]
# ### 1. What are the most common reasons for customer cancellations?

# %% [markdown]
# ### 2 What are the most common reasons for driver cancellations?

# %% [markdown]
# ### 3 How do customer cancellations compare to driver cancellations?

# %% [markdown]
# ### 4.  Which vehicle types face the highest cancellation rates?

# %% [markdown]
# ## 🔹 Driver Performance Analysis

# %% [markdown]
# ### 1. what is the average driver rating by vehicle type?

# %% [markdown]
# ### 2. What are the minimum and maximum driver ratings for Prime Sedan?

# %% [markdown]
# ### 3. How does driver rating distribution differ across vehicle types?

# %% [markdown]
# ### 4. Is there a relationship between driver ratings and ride distance?

# %% [markdown]
# ## 🔹 Payment Behavior

# %% [markdown]
# ### 1. What percentage of rides were paid using each payment method?

# %% [markdown]
# ### 2. How does payment method usage differ across vehicle types?

# %% [markdown]
# ### 3. Is there any difference in average booking value by payment method?

# %% [markdown]
# ## 🔹 Incomplete Ride Analysis

# %% [markdown]
# ### 1. What percentage of rides were incomplete?

# %% [markdown]
# ### 2. What are the most common reasons for incomplete rides?

# %% [markdown]
# ### 3. How do incomplete rides vary across vehicle types?

# %% [markdown]
# ## 🔹 Advanced / Dashboard-Level Questions

# %% [markdown]
# ### 1. What are the key KPIs for overall ride performance (Bookings, Revenue, Avg Rating, Avg Distance)?

# %% [markdown]
# ### 2. Which factors most strongly impact successful ride completion?

# %% [markdown]
# ### 3. How does customer satisfaction vary with vehicle type and payment method?

# %% [markdown]
# ### 4. What operational risks can be identified from cancellation and incomplete ride patterns?
